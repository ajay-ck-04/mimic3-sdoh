# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic
#   Downloading bertopic-0.14.1-py2.py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 kB 3.7 MB/s eta 0:00:00
# Collecting hdbscan>=0.8.29
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 35.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (4.65.0)
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (5.13.1)
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.22.4)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.2.0)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.34)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.7.0->bertopic) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 88.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.1+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 65.2 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 23.8 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 63.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.4.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.27.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.7.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (16.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 73.4 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp39-cp39-linux_x86_64.whl size=3580462 sha256=7c295168311c621bdf28137a84fc14dcc20078c8a23f3996f87c27ae1335c15e
#   Stored in directory: /root/.cache/pip/wheels/05/6f/88/1a4c04276b98306f00217a1e300e6ba0252c6aa4f7616067ae
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=b5fa50d59be13c14cd2edc576b8cdbeb45be396e525ba09818eca6f64b39630b
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82830 sha256=816936ec7ca9f33887d6e41fca525724df3015195a755032e37cf9d6657b9676
#   Stored in directory: /root/.cache/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55640 sha256=ccc80b00de532d61e3330de7682472016d2c134fa0c0f8f31a73f2ac79b0c852
#   Stored in directory: /root/.cache/pip/wheels/12/f9/4d/ec5ad1c823c710fcc4473669fdcffc8891f4bc398c841af22e
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
# Successfully installed bertopic-0.14.1 hdbscan-0.8.29 huggingface-hub-0.14.1 pynndescent-0.5.10 sentence-transformers-2.2.2 sentencepiece-0.1.98 tokenizers-0.13.3 transformers-4.28.1 umap-learn-0.5.3

# %% [markdown]
# ## LDA with basic data preprocessing

# %%
import pandas as pd
import numpy as np
import re
import nltk
import gensim 
from gensim.models.ldamulticore import LdaMulticore
from gensim import corpora, models
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from gensim.models import CoherenceModel
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
df = pd.read_pickle("/content/drive/MyDrive/mimic_cleaned_2000")

# %%
df.head()
# Out:
#    ROW_ID  SUBJECT_ID   HADM_ID   CHARTDATE CHARTTIME STORETIME  \
# 0     174       22532  167853.0  2151-08-04       NaN       NaN
# 1     175       13702  107527.0  2118-06-14       NaN       NaN
# 2     176       13702  167118.0  2119-05-25       NaN       NaN
# 3     177       13702  196489.0  2124-08-18       NaN       NaN
# 4     178       26880  135453.0  2162-03-25       NaN       NaN
#
#             CATEGORY DESCRIPTION  CGID  ISERROR  \
# 0  Discharge summary      Report   NaN      NaN
# 1  Discharge summary      Report   NaN      NaN
# 2  Discharge summary      Report   NaN      NaN
# 3  Discharge summary      Report   NaN      NaN
# 4  Discharge summary      Report   NaN      NaN
#
#                                                 TEXT
# 0   service addendum radiologic studies radiologi...
# 1   f service micu and then to medicine history o...
# 2   service cardiothoracic allergies amlodipine a...
# 3   service medicine allergies amlodipine attendi...
# 4   m service medicine allergies patient recorded...

# %%
doc_notes_lda = df['TEXT'].to_list()

# %%
doc_notes_lda[0]
# Out:
# ' service addendum radiologic studies radiologic studies also included a chest ct which confirmed cavitary lesions in the left lung apex consistent with infectious processtuberculosis this also moderatesized left pleural effusion head c head ct showed no intracranial hemorrhage or mass effect but old infarction consistent with past medical history abdominal c abdominal ct showed lesions of t and sacrum most likely secondary to osteoporosis these can be followed by repeat imaging as an outpatient md dictated by medquist '

# %% [markdown]
# ## Cleaning TEXT using NLTK

# %%
def clean_text(lst):
    cleaned_text = []
    stopword = stopwords.words("english")
    
    ## Text Cleaning (Removing Punctuations, Stopwords, Tokenization and Lemmatization)
    for text in lst:
        text = str(text).lower()
        text = re.sub(r'[^\w ]+', "", text)
        text = " ".join([lemmatizer.lemmatize(word,pos='v') for word in word_tokenize(text) if not word in set(stopword) and len(word)>3])
        cleaned_text.append(text)
        
    return cleaned_text
  
    
def make_biagram(data,tokens):
    bigram = gensim.models.Phrases(data, min_count=5, threshold=100) # higher threshold fewer phrases.
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    return [bigram_mod[doc] for doc in tokens]  
 

cleaned_notes = clean_text(doc_notes_lda)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-91178e443804> in <cell line: 21>()
#      19
#      20
# ---> 21 cleaned_notes = clean_text(doc_notes_lda)
#
# NameError: name 'doc_notes_lda' is not defined

# %%
cleaned_notes[0]
# Out:
# 'service addendum radiologic study radiologic study also include chest confirm cavitary lesions leave lung apex consistent infectious processtuberculosis also moderatesized leave pleural effusion head head show intracranial hemorrhage mass effect infarction consistent past medical history abdominal abdominal show lesions sacrum likely secondary osteoporosis follow repeat image outpatient dictate medquist'

# %% [markdown]
# ## Topic modelling using LDA

# %%
def topic_modeling(data):
    ### Tokens
    tokens = []
    for text in data:
        text = word_tokenize(text)
        tokens.append(text)
        
    ### Make Biagrams
    tokens = make_biagram(data=data,tokens=tokens)

    ### Corpora Dictionary
    dictionary = corpora.Dictionary(tokens)
    
    ### Creating Document Term Matrix
    doc_term_matrix = [dictionary.doc2bow(doc) for doc in tokens]

    ### Training The LDA Model
    lda_model =  gensim.models.LdaModel(doc_term_matrix,   ## Document Term Matrix
                                       num_topics = 12,     ## Number of Topics
                                       id2word = dictionary,     ## Word and Frequency Dictionary                                
                                       passes = 10,        ## Number of passes throw the corpus during training (similar to epochs in neural networks)
                                       chunksize=10,       ## Number of documents to be used in each training chunk
                                       update_every=1,     ## Number of documents to be iterated through for each update.
                                       alpha='auto',       ## number of expected topics that expresses
                                       per_word_topics=True,
                                       random_state=42)
    
    cm = CoherenceModel(model=lda_model, corpus=doc_term_matrix, texts=tokens, coherence='c_v')
    coherence_lda = cm.get_coherence()

    ### Exploring Common Words For Each Topic With Their Relative Words
    for idx, topic in lda_model.print_topics():
        print("Topic: {} \nWords: {}".format(idx, topic ))
        print("\n")
    print("Coherence score:",coherence_lda)

topic_modeling(cleaned_notes)
# Out:
# Topic: 0
# Words: 0.116*"fracture" + 0.040*"fall" + 0.036*"spine" + 0.026*"spinal" + 0.025*"vertebral" + 0.022*"cord" + 0.020*"signal" + 0.020*"reduce" + 0.019*"compression" + 0.019*"collar"
#
#
# Topic: 1
# Words: 0.032*"leave" + 0.026*"right" + 0.015*"head" + 0.009*"follow" + 0.008*"intact" + 0.008*"mass" + 0.007*"bilaterally" + 0.007*"hemorrhage" + 0.007*"discharge" + 0.006*"weakness"
#
#
# Topic: 2
# Words: 0.073*"patient" + 0.017*"history" + 0.014*"time" + 0.014*"discharge" + 0.012*"status" + 0.011*"patients" + 0.011*"rate" + 0.011*"pressure" + 0.010*"care" + 0.009*"hospital"
#
#
# Topic: 3
# Words: 0.040*"inhalation" + 0.040*"albuterol" + 0.030*"breath" + 0.027*"puff" + 0.027*"cough" + 0.026*"prednisone" + 0.026*"copd" + 0.024*"lung" + 0.023*"pulmonary" + 0.023*"wheeze"
#
#
# Topic: 4
# Words: 0.000*"hamate" + 0.000*"movment" + 0.000*"communited" + 0.000*"ctlso" + 0.000*"errands" + 0.000*"fracures" + 0.000*"toxicities" + 0.000*"styloid" + 0.000*"platform" + 0.000*"signd"
#
#
# Topic: 5
# Words: 0.088*"tablet" + 0.058*"daily" + 0.021*"discharge" + 0.019*"capsule" + 0.018*"need" + 0.017*"please" + 0.016*"time" + 0.016*"pain" + 0.015*"every" + 0.015*"tablets"
#
#
# Topic: 6
# Words: 0.050*"blood" + 0.015*"discharge" + 0.015*"history" + 0.011*"admission" + 0.011*"give" + 0.011*"deny" + 0.009*"pain" + 0.008*"acute" + 0.008*"glucose" + 0.008*"present"
#
#
# Topic: 7
# Words: 0.000*"hamate" + 0.000*"movment" + 0.000*"communited" + 0.000*"ctlso" + 0.000*"errands" + 0.000*"fracures" + 0.000*"toxicities" + 0.000*"styloid" + 0.000*"platform" + 0.000*"signd"
#
#
# Topic: 8
# Words: 0.034*"artery" + 0.028*"leave" + 0.024*"cardiac" + 0.023*"coronary" + 0.017*"disease" + 0.013*"aspirin" + 0.012*"stenosis" + 0.012*"graft" + 0.009*"chest" + 0.009*"aortic"
#
#
# Topic: 9
# Words: 0.022*"leave" + 0.021*"normal" + 0.020*"right" + 0.015*"see" + 0.014*"valve" + 0.014*"ventricular" + 0.013*"mild" + 0.011*"pulmonary" + 0.011*"aortic" + 0.010*"systolic"
#
#
# Topic: 10
# Words: 0.016*"patient" + 0.014*"culture" + 0.012*"negative" + 0.010*"give" + 0.009*"continue" + 0.008*"abdominal" + 0.008*"place" + 0.007*"course" + 0.007*"fluid" + 0.007*"line"
#
#
# Topic: 11
# Words: 0.055*"seizure" + 0.047*"dilantin" + 0.040*"seizures" + 0.024*"parietal" + 0.020*"laboratories" + 0.020*"barbitrtneg" + 0.018*"multifactorial" + 0.017*"bnzodzpnneg" + 0.017*"penicillin" + 0.016*"neurontin"
#
#
# Coherence score: 0.4807778990625087

# %% [markdown]
# ## Topic modelling using BERT topic

# %%
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

# we add this to remove stopwords
vectorizer_model = CountVectorizer(ngram_range=(1, 4), stop_words="english")

# %%
model = BERTopic(
    vectorizer_model=vectorizer_model,
    language='english', calculate_probabilities=True,
    verbose=True
)
topics, probs = model.fit_transform(doc_notes_lda)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Batches:   0%|          | 0/63 [00:00<?, ?it/s]
# 2023-04-23 00:26:27,407 - BERTopic - Transformed documents to Embeddings
# 2023-04-23 00:26:46,297 - BERTopic - Reduced dimensionality
# 2023-04-23 00:26:46,634 - BERTopic - Clustered reduced embeddings

# %%
freq = model.get_topic_info()
freq
# Out:
#     Topic  Count                            Name
# 0      -1    830          -1_mg_patient_po_blood
# 1       0    173            0_mg_tablet_daily_po
# 2       1    137              1_tablet_mg_po_sig
# 3       2    107           2_patient_mg_blood_po
# 4       3     90            3_mg_tablet_daily_po
# 5       4     83         4_right_left_mg_patient
# 6       5     75            5_mg_tablet_daily_po
# 7       6     55    6_patient_coronary_artery_mg
# 8       7     54          7_mg_patient_po_tablet
# 9       8     47         8_right_left_mg_patient
# 10      9     42              9_mg_tablet_po_sig
# 11     10     39        10_blood_pain_patient_mg
# 12     11     35          11_patient_mg po_mg_po
# 13     12     31       12_patient_mg_tablet_pain
# 14     13     30           13_mg_tablet_po_daily
# 15     14     26          14_mg_hip_tablet_daily
# 16     15     24           15_mg_po_tablet_renal
# 17     16     24             16_tablet_sig_po_mg
# 18     17     23         17_patient_mg_blood_day
# 19     18     23   18_withdrawal_alcohol_mg_etoh
# 20     19     16  19_seizure_mg_patient_seizures
# 21     20     13   20_patient_mg po_right_artery
# 22     21     12         21_right_pain_mg_tablet
# 23     22     11         22_patient_mg_day_mg po

# %%
model.visualize_barchart(top_n_topics=12)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e9eb00ab-b412-404c-87c5-764375c30896" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9eb00ab-b412-404c-87c5-764375c30896")) {                    Plotly.newPlot(                        "e9eb00ab-b412-404c-87c5-764375c30896",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.007642837568258198,0.00792111557246674,0.00797176671205508,0.008962598398614557,0.010795159235262941],"y":["blood  ","po  ","daily  ","tablet  ","mg  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.009963500086568423,0.010161723654455366,0.010676127504329423,0.011842417200146883,0.014145875379535915],"y":["daily  ","sig  ","po  ","mg  ","tablet  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.006609329251315535,0.007167465376494498,0.008567533617720903,0.008985463853083327,0.010254087705361768],"y":["tablet  ","po  ","blood  ","mg  ","patient  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.0067219712954326525,0.007691272024826319,0.009298471441620585,0.010506220892885458,0.010816811179681187],"y":["sig  ","po  ","daily  ","tablet  ","mg  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.0070408288407219155,0.008161048973246364,0.008315775965057412,0.010004127017992514,0.01019230436528164],"y":["po  ","patient  ","mg  ","left  ","right  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.00717189587020203,0.007892639113577904,0.008447566309714714,0.009302832147502571,0.011444755893278334],"y":["sig  ","po  ","daily  ","tablet  ","mg  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.010541173150436012,0.01188980951660459,0.012611822665058198,0.01319908688685837,0.02029989848191447],"y":["day  ","mg  ","artery  ","coronary  ","patient  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.006110966731822016,0.0074618441476674985,0.008411932612432595,0.009130166052023577,0.010344425631990006],"y":["sig  ","tablet  ","po  ","patient  ","mg  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.005737431067369341,0.007261735584551403,0.007642970618259376,0.007997767697565075,0.008759193895554901],"y":["po  ","patient  ","mg  ","left  ","right  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.007130787914465639,0.007843645184068906,0.007983838898087384,0.008477339183962403,0.010452861611387334],"y":["daily  ","sig  ","po  ","tablet  ","mg  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.006846801381926326,0.007945139769972026,0.008054405454768808,0.008869148785264748,0.011784569328994526],"y":["tablet  ","mg  ","patient  ","pain  ","blood  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.012480006263268891,0.015198543167793508,0.01710121099378197,0.01904545513652299,0.022718963810201675],"y":["postoperative  ","po  ","mg  ","mg po  ","patient  "],"type":"bar","xaxis":"x12","yaxis":"y12"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3 ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="69e31573-20af-4040-ae1e-daa7243bf055" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69e31573-20af-4040-ae1e-daa7243bf055")) {                    Plotly.newPlot(                        "69e31573-20af-4040-ae1e-daa7243bf055",                        [{"customdata":[[0,"mg | tablet | daily | po | blood",173],[1,"tablet | mg | po | sig | daily",137],[2,"patient | mg | blood | po | tablet",107],[3,"mg | tablet | daily | po | sig",90],[4,"right | left | mg | patient | po",83],[5,"mg | tablet | daily | po | sig",75],[6,"patient | coronary | artery | mg | day",55],[7,"mg | patient | po | tablet | sig",54],[8,"right | left | mg | patient | po",47],[9,"mg | tablet | po | sig | daily",42],[10,"blood | pain | patient | mg | tablet",39],[11,"patient | mg po | mg | po | postoperative",35],[12,"patient | mg | tablet | pain | po",31],[13,"mg | tablet | po | daily | sig",30],[14,"mg | hip | tablet | daily | po",26],[15,"mg | po | tablet | renal | pm",24],[16,"tablet | sig | po | mg | daily",24],[17,"patient | mg | blood | day | history",23],[18,"withdrawal | alcohol | mg | etoh | daily",23],[19,"seizure | mg | patient | seizures | tablet",16],[20,"patient | mg po | right | artery | mg",13],[21,"right | pain | mg | tablet | chest",12],[22,"patient | mg | day | mg po | heart",11]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>%{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[173,137,107,90,83,75,55,54,47,42,39,35,31,30,26,24,24,23,23,16,13,12,11],"sizemode":"area","sizeref":0.108125,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[6.6924662590026855,7.756071090698242,7.129823684692383,7.450847148895264,-5.562793254852295,6.944163799285889,11.846925735473633,-13.081354141235352,-5.643411636352539,-13.063005447387695,4.737328052520752,12.087889671325684,4.637606620788574,6.853630065917969,-28.558757781982422,9.090890884399414,-28.451927185058594,13.133391380310059,9.030128479003906,8.752866744995117,12.459392547607422,-28.279775619506836,12.866294860839844],"xaxis":"x","y":[2.262371301651001,1.7586162090301514,2.4150593280792236,1.8790760040283203,18.75566864013672,2.0385642051696777,-0.6594844460487366,12.953202247619629,18.837158203125,12.970979690551758,6.8799147605896,-0.9142391681671143,6.979745388031006,2.591895580291748,-4.009390830993652,12.405939102172852,-3.9025659561157227,-1.4367213249206543,12.344870567321777,12.067621231079102,-1.095707654953003,-3.7304208278656006,-1.2397104501724243],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333 ...

# %%
# New data for the review
new_review = "The patient needs help with transportation as they have no car."
# Find topics
num_of_topics = 5
similar_topics, similarity = model.find_topics(new_review, top_n=num_of_topics); 
# Print results
print(f'The top {num_of_topics} similar topics are {similar_topics}, and the similarities are {np.round(similarity,2)}')
# Out:
# The top 5 similar topics are [20, 6, 11, 17, 22], and the similarities are [0.32 0.3  0.3  0.26 0.25]

# %%
for i in range(num_of_topics):
  print(f'The top keywords for topic {similar_topics[i]} are:')
  print(model.get_topic(similar_topics[i]))
# Out:
# The top keywords for topic 20 are:
# [('patient', 0.019038962013316448), ('mg po', 0.010021392760706105), ('right', 0.00986214773807221), ('artery', 0.009662620182270222), ('mg', 0.00954520212818694), ('patients', 0.008717518478099496), ('po', 0.0082760366322519), ('coronary', 0.008226810325584663), ('day', 0.00800870406553924), ('graft', 0.006694676469375733)]
# The top keywords for topic 6 are:
# [('patient', 0.02029989848191447), ('coronary', 0.01319908688685837), ('artery', 0.012611822665058198), ('mg', 0.01188980951660459), ('day', 0.010541173150436012), ('coronary artery', 0.009930185367098773), ('catheterization', 0.009088447409219848), ('left', 0.009069532611270918), ('mg po', 0.00811004867790935), ('po', 0.007434632067548949)]
# The top keywords for topic 11 are:
# [('patient', 0.022718963810201675), ('mg po', 0.01904545513652299), ('mg', 0.01710121099378197), ('po', 0.015198543167793508), ('postoperative', 0.012480006263268891), ('day', 0.011864148669848645), ('qd', 0.011821048287732993), ('postoperative day', 0.011354550702178268), ('artery', 0.01109823488295005), ('coronary', 0.010999765883816626)]
# The top keywords for topic 17 are:
# [('patient', 0.018249154880112715), ('mg', 0.00996215278955537), ('blood', 0.00933627464238043), ('day', 0.008853642909724523), ('history', 0.006887844060386789), ('po', 0.00682175683017054), ('mg po', 0.006808769275022053), ('heart', 0.006452757837579017), ('hospital', 0.006366735230035268), ('failure', 0.00631584363424234)]
# The top keywords for topic 22 are:
# [('patient', 0.01775725318877988), ('mg', 0.012563231360253122), ('day', 0.010049247516465933), ('mg po', 0.00861653468938485), ('heart', 0.008248485122918444), ('po', 0.007922019998631881), ('left', 0.007661397537007539), ('pressure', 0.007617244634376554), ('congestive heart', 0.007545468349299594), ('congestive', 0.00749978366444791)]

# %%
model.save("BERT_topic_vector")

# %% [markdown]
# ## BERTTopic with UMAP modelling

# %%
# Initiate UMAP
from umap import UMAP
umap_model = UMAP(n_neighbors=15, 
                  n_components=5, 
                  min_dist=0.0, 
                  metric='cosine', 
                  random_state=100)
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, language="english", calculate_probabilities=True)
# Run BERTopic model
topics, probabilities = topic_model.fit_transform(cleaned_notes)
# Out:
# 2023-04-23 00:51:11,029 - BERTopic - Transformed documents to Embeddings
# 2023-04-23 00:51:19,730 - BERTopic - Reduced dimensionality
# 2023-04-23 00:51:19,922 - BERTopic - Clustered reduced embeddings

# %%
topic_model.visualize_barchart(top_n_topics=12)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="45ad6e45-77e4-48e2-8913-ec69ebb90612" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45ad6e45-77e4-48e2-8913-ec69ebb90612")) {                    Plotly.newPlot(                        "45ad6e45-77e4-48e2-8913-ec69ebb90612",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.015950823116697415,0.016158105410516776,0.01764100074023131,0.020859274780309408,0.022627118531425173],"y":["patient  ","discharge  ","head  ","leave  ","right  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.013241803322068238,0.015515212097280713,0.015529458578254022,0.021624215528761367,0.023159825884583367],"y":["history  ","blood  ","discharge  ","daily  ","tablet  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.016391097510578954,0.016413456918406403,0.01759920747764325,0.019784644903092657,0.022248030550637937],"y":["discharge  ","patient  ","daily  ","tablet  ","blood  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.028776515297849047,0.029050440448235158,0.03883889251189707,0.04050607155598408,0.043269315286637036],"y":["graft  ","postoperative  ","artery  ","coronary  ","patient  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.014603187637771853,0.015525493783857092,0.01872076980358549,0.01935107203152865,0.020635114803203927],"y":["discharge  ","patient  ","daily  ","blood  ","tablet  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.016478980109648735,0.016495515194755887,0.016694707428110103,0.016746456751576596,0.021131796099194668],"y":["cancer  ","lung  ","right  ","tablet  ","patient  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.01654446284281591,0.017706258222403674,0.019898104681489035,0.021317416658769208,0.04746544811676838],"y":["history  ","blood  ","pressure  ","patients  ","patient  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01995424127410455,0.020253527249264804,0.02241140523602051,0.02485296921188389,0.04220527822386186],"y":["blood  ","bleed  ","history  ","hematocrit  ","patient  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.020193101576762337,0.023560399073543778,0.02419339229038247,0.024799244611549295,0.02480956334520604],"y":["cardiac  ","chest  ","pain  ","tablet  ","daily  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.027761159264385243,0.027992720021314053,0.029298724355315314,0.029319045465314667,0.0357698401035598],"y":["artery  ","daily  ","aortic  ","leave  ","tablet  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.017539489735015887,0.018175496518165656,0.018873127138157465,0.020287266483117954,0.026262989710541453],"y":["discharge  ","etoh  ","history  ","alcohol  ","withdrawal  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.018690529935419913,0.01943874752832343,0.019644995947268488,0.026023433871576362,0.027073136639085907],"y":["leave  ","pain  ","daily  ","fracture  ","tablet  "],"type":"bar","xaxis":"x12","yaxis":"y12"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode" ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e761366c-71c7-43f6-a1f1-ef2745e18569" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e761366c-71c7-43f6-a1f1-ef2745e18569")) {                    Plotly.newPlot(                        "e761366c-71c7-43f6-a1f1-ef2745e18569",                        [{"customdata":[[0,"right | leave | head | discharge | patient",152],[1,"tablet | daily | discharge | blood | history",138],[2,"blood | tablet | daily | patient | discharge",97],[3,"patient | coronary | artery | postoperative | graft",86],[4,"tablet | blood | daily | patient | discharge",84],[5,"patient | tablet | right | lung | cancer",82],[6,"patient | patients | pressure | blood | history",62],[7,"patient | hematocrit | history | bleed | blood",53],[8,"daily | tablet | pain | chest | cardiac",53],[9,"tablet | leave | aortic | daily | artery",49],[10,"withdrawal | alcohol | history | etoh | discharge",44],[11,"tablet | fracture | daily | pain | leave",44],[12,"pain | blood | bowel | patient | discharge",33],[13,"valve | mitral | tablet | aortic | disp",26],[14,"tablet | daily | atrial | ventricular | pericardial",26],[15,"ercp | duct | biliary | tablet | pain",23],[16,"transplant | renal | tablet | units | patient",21],[17,"blood | tablet | right | leave | give",20],[18,"blood | discharge | tablet | right | fracture",14],[19,"blood | liver | tablet | portal | totbili",11],[20,"patient | mitral | regurgitation | artery | postoperative",11],[21,"tablet | daily | valve | leave | aortic",11],[22,"patient | pulmonary | oxygen | history | obstructive",11]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>%{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[152,138,97,86,84,82,62,53,53,49,44,44,33,26,26,23,21,20,14,11,11,11,11],"sizemode":"area","sizeref":0.095,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[15.302522659301758,-8.99886417388916,-9.266105651855469,-1.2380234003067017,-9.404614448547363,-0.4784575402736664,-0.7426372766494751,-0.4683285057544708,13.940885543823242,18.728801727294922,14.783510208129883,14.860995292663574,19.60586166381836,18.492000579833984,14.116503715515137,19.652441024780273,14.365455627441406,14.898189544677734,19.867422103881836,14.431035995483398,-1.4377055168151855,18.378002166748047,-0.3216851055622101],"xaxis":"x","y":[-1.0144827365875244,-6.559018135070801,-6.826229572296143,9.161355972290039,-6.964747428894043,8.77149772644043,9.370929718017578,9.194843292236328,-0.06887579709291458,-20.0028133392334,-0.5365201234817505,-0.9447110891342163,27.77986717224121,-19.765844345092773,-0.34738844633102417,27.82644271850586,-1.4217160940170288,-1.090377688407898,28.041391372680664,-1.5218130350112915,8.853141784667969,-19.65181541442871,9.6117525100708],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb( ...

# %%
# New data for the review
new_review = "The patient needs help with transportation as they have no car."
# Find topics
num_of_topics = 5
similar_topics, similarity = model.find_topics(new_review, top_n=num_of_topics); 
# Print results
print(f'The top {num_of_topics} similar topics are {similar_topics}, and the similarities are {np.round(similarity,2)}')
# Out:
# The top 5 similar topics are [20, 6, 11, 17, 22], and the similarities are [0.32 0.3  0.3  0.26 0.25]

# %%
for i in range(num_of_topics):
  print(f'The top keywords for topic {similar_topics[i]} are:')
  print(model.get_topic(similar_topics[i]))
# Out:
# The top keywords for topic 20 are:
# [('patient', 0.019038962013316448), ('mg po', 0.010021392760706105), ('right', 0.00986214773807221), ('artery', 0.009662620182270222), ('mg', 0.00954520212818694), ('patients', 0.008717518478099496), ('po', 0.0082760366322519), ('coronary', 0.008226810325584663), ('day', 0.00800870406553924), ('graft', 0.006694676469375733)]
# The top keywords for topic 6 are:
# [('patient', 0.02029989848191447), ('coronary', 0.01319908688685837), ('artery', 0.012611822665058198), ('mg', 0.01188980951660459), ('day', 0.010541173150436012), ('coronary artery', 0.009930185367098773), ('catheterization', 0.009088447409219848), ('left', 0.009069532611270918), ('mg po', 0.00811004867790935), ('po', 0.007434632067548949)]
# The top keywords for topic 11 are:
# [('patient', 0.022718963810201675), ('mg po', 0.01904545513652299), ('mg', 0.01710121099378197), ('po', 0.015198543167793508), ('postoperative', 0.012480006263268891), ('day', 0.011864148669848645), ('qd', 0.011821048287732993), ('postoperative day', 0.011354550702178268), ('artery', 0.01109823488295005), ('coronary', 0.010999765883816626)]
# The top keywords for topic 17 are:
# [('patient', 0.018249154880112715), ('mg', 0.00996215278955537), ('blood', 0.00933627464238043), ('day', 0.008853642909724523), ('history', 0.006887844060386789), ('po', 0.00682175683017054), ('mg po', 0.006808769275022053), ('heart', 0.006452757837579017), ('hospital', 0.006366735230035268), ('failure', 0.00631584363424234)]
# The top keywords for topic 22 are:
# [('patient', 0.01775725318877988), ('mg', 0.012563231360253122), ('day', 0.010049247516465933), ('mg po', 0.00861653468938485), ('heart', 0.008248485122918444), ('po', 0.007922019998631881), ('left', 0.007661397537007539), ('pressure', 0.007617244634376554), ('congestive heart', 0.007545468349299594), ('congestive', 0.00749978366444791)]

# %%
topic_model.save("BERT_topic_umap")

# %%
df_transport = pd.read_pickle("/content/drive/MyDrive/transport_notes_cleaned_2000")

# %%
df_transport.head()
# Out:
#    index  ROW_ID  SUBJECT_ID   HADM_ID   CHARTDATE CHARTTIME STORETIME  \
# 0     48     195       22180  162436.0  2134-03-09       NaN       NaN
# 1    490     500       17977  198062.0  2159-11-10       NaN       NaN
# 2   1581    1546       79061  127004.0  2153-07-28       NaN       NaN
# 3   1673    1314       75733  151447.0  2132-05-23       NaN       NaN
# 4   2086    1865       22208  143545.0  2179-03-22       NaN       NaN
#
#             CATEGORY DESCRIPTION  CGID  ISERROR  \
# 0  Discharge summary      Report   NaN      NaN
# 1  Discharge summary      Report   NaN      NaN
# 2  Discharge summary      Report   NaN      NaN
# 3  Discharge summary      Report   NaN      NaN
# 4  Discharge summary      Report   NaN      NaN
#
#                                                 TEXT  TRANSPORTATION
# 0   service medicine allergies patient recorded a...               1
# 1   f service medicine allergies losartan aspirin...               1
# 2   m service medicine allergies patient recorded...               1
# 3   m service medicine allergies ampicillin penic...               1
# 4   m service medicine allergies benzodiazepines ...               1

# %%
df_transport = df_transport.iloc[:479]

# %%
doc_notes = df_transport['TEXT'].to_list()

# %% [markdown]
# ## LDA with 480 text files

# %%
def clean_text(lst):
    cleaned_text = []
    stopword = stopwords.words("english")
    
    ## Text Cleaning (Removing Punctuations, Stopwords, Tokenization and Lemmatization)
    for text in lst:
        text = str(text).lower()
        text = re.sub(r'[^\w ]+', "", text)
        text = " ".join([lemmatizer.lemmatize(word,pos='v') for word in word_tokenize(text) if not word in set(stopword) and len(word)>3])
        cleaned_text.append(text)
        
    return cleaned_text
  
    
def make_biagram(data,tokens):
    bigram = gensim.models.Phrases(data, min_count=5, threshold=100) # higher threshold fewer phrases.
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    return [bigram_mod[doc] for doc in tokens]

# %%
cleaned_notes_1 = clean_text(doc_notes)

# %%
def topic_modeling(data):
    ### Tokens
    tokens = []
    for text in data:
        text = word_tokenize(text)
        tokens.append(text)
        
    ### Make Biagrams
    tokens = make_biagram(data=data,tokens=tokens)

    ### Corpora Dictionary
    dictionary = corpora.Dictionary(tokens)
    
    ### Creating Document Term Matrix
    doc_term_matrix = [dictionary.doc2bow(doc) for doc in tokens]

    ### Training The LDA Model
    lda_model =  gensim.models.LdaModel(doc_term_matrix,       ## Document Term Matrix
                                       num_topics = 12,          ## Number of Topics
                                       id2word = dictionary,     ## Word and Frequency Dictionary                                
                                       passes = 10,            ## Number of passes throw the corpus during training (similar to epochs in neural networks)
                                       chunksize=10,           ## Number of documents to be used in each training chunk
                                       update_every=1,        ## Number of documents to be iterated through for each update.
                                       alpha='auto',           ## number of expected topics that expresses
                                       per_word_topics=True,
                                       random_state=42)
    
    cm = CoherenceModel(model=lda_model, corpus=doc_term_matrix, texts=tokens, coherence='c_v')
    coherence_lda = cm.get_coherence()

    ### Exploring Common Words For Each Topic With Their Relative Words
    for idx, topic in lda_model.print_topics():
        print("Topic: {} \nWords: {}".format(idx, topic ))
        print("\n")
    print("Coherence score:",coherence_lda)

topic_modeling(cleaned_notes_1)
# Out:
# Topic: 0
# Words: 0.036*"mother" + 0.034*"infant" + 0.024*"transportation" + 0.018*"support" + 0.017*"family" + 0.017*"plan" + 0.016*"work" + 0.016*"social" + 0.016*"visit" + 0.015*"state"
#
#
# Topic: 1
# Words: 0.015*"normal" + 0.011*"patient" + 0.011*"history" + 0.010*"chest" + 0.009*"closely" + 0.009*"interest" + 0.009*"negative" + 0.008*"blood" + 0.008*"daily" + 0.008*"leave"
#
#
# Topic: 2
# Words: 0.099*"spit" + 0.057*"loop" + 0.046*"cpap" + 0.034*"encourage" + 0.030*"jaundice" + 0.018*"pillow" + 0.015*"problems" + 0.011*"brother" + 0.010*"rebound" + 0.010*"dress"
#
#
# Topic: 3
# Words: 0.031*"drift" + 0.016*"extend" + 0.012*"safety" + 0.012*"intervention" + 0.011*"cord" + 0.009*"discussion" + 0.009*"unremarkable" + 0.009*"pattern" + 0.009*"impression" + 0.009*"long"
#
#
# Topic: 4
# Words: 0.073*"understand" + 0.022*"secretions" + 0.019*"yellow" + 0.007*"thick" + 0.005*"role" + 0.004*"trach" + 0.003*"peep" + 0.002*"device" + 0.001*"multifocal" + 0.001*"copd"
#
#
# Topic: 5
# Words: 0.005*"approach" + 0.002*"admissions" + 0.000*"incr" + 0.000*"contingent" + 0.000*"buncr" + 0.000*"clarification" + 0.000*"caloric" + 0.000*"immature" + 0.000*"tricare" + 0.000*"thru"
#
#
# Topic: 6
# Words: 0.034*"feed" + 0.033*"cont" + 0.025*"stable" + 0.023*"monitor" + 0.020*"continue" + 0.019*"remain" + 0.016*"stool" + 0.015*"note" + 0.015*"soft" + 0.015*"well"
#
#
# Topic: 7
# Words: 0.000*"blockages" + 0.000*"company" + 0.000*"age" + 0.000*"ampm" + 0.000*"angiographically" + 0.000*"areless" + 0.000*"bblocker" + 0.000*"binge" + 0.000*"blockage" + 0.000*"yankauer"
#
#
# Topic: 8
# Words: 0.060*"yesterday" + 0.034*"husband" + 0.026*"sister" + 0.025*"members" + 0.020*"drive" + 0.016*"supportive" + 0.013*"appreciate" + 0.009*"get" + 0.009*"little" + 0.009*"encourage"
#
#
# Topic: 9
# Words: 0.000*"blockages" + 0.000*"company" + 0.000*"age" + 0.000*"ampm" + 0.000*"angiographically" + 0.000*"areless" + 0.000*"bblocker" + 0.000*"binge" + 0.000*"blockage" + 0.000*"yankauer"
#
#
# Topic: 10
# Words: 0.000*"blockages" + 0.000*"company" + 0.000*"age" + 0.000*"ampm" + 0.000*"angiographically" + 0.000*"areless" + 0.000*"bblocker" + 0.000*"binge" + 0.000*"blockage" + 0.000*"yankauer"
#
#
# Topic: 11
# Words: 0.043*"teach" + 0.011*"friends" + 0.011*"liter" + 0.009*"run" + 0.008*"cath" + 0.005*"cchr" + 0.003*"stent" + 0.002*"verbal" + 0.002*"groin" + 0.002*"stemi"
#
#
# Coherence score: 0.43374691800057125

# %% [markdown]
# ## BERT Topic modelling with 480 text files

# %%
model_480 = BERTopic(
    vectorizer_model=vectorizer_model,
    language='english', calculate_probabilities=True,
    verbose=True
)
topics, probs = model_480.fit_transform(cleaned_notes_1)
# Out:
# Batches:   0%|          | 0/15 [00:00<?, ?it/s]
# 2023-04-23 01:01:41,706 - BERTopic - Transformed documents to Embeddings
# 2023-04-23 01:01:44,798 - BERTopic - Reduced dimensionality
# 2023-04-23 01:01:44,834 - BERTopic - Clustered reduced embeddings

# %%
model_480.visualize_barchart(top_n_topics=12)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f3fed82e-33b9-4151-8c99-b4e9a070d1da" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3fed82e-33b9-4151-8c99-b4e9a070d1da")) {                    Plotly.newPlot(                        "f3fed82e-33b9-4151-8c99-b4e9a070d1da",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01709890806088182,0.01888877709922989,0.022229658340846902,0.022967075362640903,0.03684280401395678],"y":["state  ","transportation  ","work  ","family  ","mother  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.008838489405810446,0.009484092588926045,0.011342440876695729,0.011530142838781633,0.011874410452328904],"y":["daily  ","leave  ","blood  ","patient  ","tablet  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.01892886703117622,0.019035508709726916,0.022109810364896388,0.02714307995015563,0.034827343584622444],"y":["continue  ","monitor  ","cont  ","feed  ","infant  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.010475130660231518,0.010637902235185336,0.01089840328499948,0.013529724152025918,0.014685664820252303],"y":["transportation  ","wife  ","neuro  ","note  ","cont  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.02298157655121576,0.023666614113812327,0.024317669978157957,0.02487089949908032,0.028559486606999362],"y":["assessment  ","receive  ","plan  ","action  ","response  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.025834709842008925,0.026613272511747044,0.03357602605115394,0.03424970052150271,0.04105440500625986],"y":["attend  ","transportation  ","feed  ","neonatology attend  ","neonatology  "],"type":"bar","xaxis":"x6","yaxis":"y6"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0. ...

# %%
model_480.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="041d27da-c22b-428c-bf1f-9798bb67c121" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("041d27da-c22b-428c-bf1f-9798bb67c121")) {                    Plotly.newPlot(                        "041d27da-c22b-428c-bf1f-9798bb67c121",                        [{"customdata":[[0,"mother | family | work | transportation | state",150],[1,"tablet | patient | blood | leave | daily",125],[2,"infant | feed | cont | monitor | continue",123],[3,"cont | note | neuro | wife | transportation",40],[4,"response | action | plan | receive | assessment",17],[5,"neonatology | neonatology attend | feed | transportation | attend",15]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>%{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[150,125,123,40,17,15],"sizemode":"area","sizeref":0.09375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[3.870298385620117,1.8656721115112305,2.4129385948181152,2.280792474746704,2.724552631378174,2.8943049907684326],"xaxis":"x","y":[19.92369270324707,18.331796646118164,20.18535804748535,18.925090789794922,18.16588020324707,19.83733558654785],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0 ...

# %%
# New data for the review
new_review = "The patient needs help with transportation as they have no car."
# Find topics
num_of_topics = 5
similar_topics, similarity = model_480.find_topics(new_review, top_n=num_of_topics); 
# Print results
print(f'The top {num_of_topics} similar topics are {similar_topics}, and the similarities are {np.round(similarity,2)}')
# Out:
# The top 5 similar topics are [5, 0, 2, 1, 3], and the similarities are [0.31 0.23 0.21 0.21 0.2 ]

# %%
for i in range(num_of_topics):
  print(f'The top keywords for topic {similar_topics[i]} are:')
  print(model_480.get_topic(similar_topics[i]))
# Out:
# The top keywords for topic 5 are:
# [('neonatology', 0.04105440500625986), ('neonatology attend', 0.03424970052150271), ('feed', 0.03357602605115394), ('transportation', 0.026613272511747044), ('attend', 0.025834709842008925), ('stool', 0.02564450356642722), ('attend weeks', 0.02488249432387608), ('neonatology attend weeks', 0.02488249432387608), ('stable', 0.024395688119004822), ('continue', 0.023184240386368057)]
# The top keywords for topic 0 are:
# [('mother', 0.03684280401395678), ('family', 0.022967075362640903), ('work', 0.022229658340846902), ('transportation', 0.01888877709922989), ('state', 0.01709890806088182), ('meet', 0.016450909799992235), ('social', 0.01573693533634609), ('social work', 0.01528084842612946), ('need', 0.014527504529420447), ('home', 0.014390117694534608)]
# The top keywords for topic 2 are:
# [('infant', 0.034827343584622444), ('feed', 0.02714307995015563), ('cont', 0.022109810364896388), ('monitor', 0.019035508709726916), ('continue', 0.01892886703117622), ('care', 0.017651419671125945), ('stable', 0.016521808846387733), ('support', 0.016290820472985083), ('today', 0.015259480906669237), ('transportation', 0.015113583471363264)]
# The top keywords for topic 1 are:
# [('tablet', 0.011874410452328904), ('patient', 0.011530142838781633), ('blood', 0.011342440876695729), ('leave', 0.009484092588926045), ('daily', 0.008838489405810446), ('discharge', 0.007969143900902859), ('history', 0.007850751305852721), ('pain', 0.007813259493971651), ('right', 0.007255887171502685), ('time', 0.005796976982934178)]
# The top keywords for topic 3 are:
# [('cont', 0.014685664820252303), ('note', 0.013529724152025918), ('neuro', 0.01089840328499948), ('wife', 0.010637902235185336), ('transportation', 0.010475130660231518), ('remain', 0.010109851378827299), ('social', 0.009126501284563918), ('skin', 0.008758244278850127), ('clear', 0.008434574590478942), ('sats', 0.00838753546055607)]
